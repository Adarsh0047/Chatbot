# %%
import pandas as pd
from itertools import chain
df = pd.read_csv("final_df.csv")

# %%
unique_skills = []
for index, row in df.iterrows():
    skills = row["SKILLS"].strip('][').split(', ')
    for skill in skills:
        unique_skills.append(skills)

# %%
unique_skills = list(chain.from_iterable(unique_skills))

# %%
i = 0
for skill in unique_skills:
    if skill.startswith("\'") and skill.endswith("\'"):
        unique_skills[i] = skill[1:-1]
    elif skill.startswith("\'") and not(skill.endswith("\'")):
        unique_skills[i] = skill[1:]
    elif not(skill.startswith("\'")) and skill.endswith("\'"):
        unique_skills[i] = skill[:-1]
    else:
        unique_skills[i] = skill
    i += 1

# %%
unique_skills = list(set(unique_skills))

# %%
for skill in unique_skills:
    if skill.startswith("\'") and skill.endswith("\'"):
        print(skill)

# %%
unique_skills = [skill.lower() for skill in unique_skills]

# %%
def remove_punct(word):
    for punctuation in [".", ","]:
        word = word.replace(punctuation, '')
    return word

# %%
unique_skills = [remove_punct(skill) for skill in unique_skills]

# %%
with open('unq_words.txt','w') as file:
	file.write('\n'.join(unique_skills))

# %%
import nltk
from collections import Counter

df = pd.read_csv("final_df.csv")

text = "This is a sample text to show the calculation of trigram frequency. This text can be replaced with any other text."

# tokenize the text into words
words = nltk.word_tokenize(text)

# generate trigrams
trigrams = nltk.ngrams(words, 3)

# count the frequency of each trigram
triFreq = Counter(trigrams)

# print the frequency of trigrams
print(triFreq)
# Out:
# Counter({('This', 'is', 'a'): 1, ('is', 'a', 'sample'): 1, ('a', 'sample', 'text'): 1, ('sample', 'text', 'to'): 1, ('text', 'to', 'show'): 1, ('to', 'show', 'the'): 1, ('show', 'the', 'calculation'): 1, ('the', 'calculation', 'of'): 1, ('calculation', 'of', 'trigram'): 1, ('of', 'trigram', 'frequency'): 1, ('trigram', 'frequency', '.'): 1, ('frequency', '.', 'This'): 1, ('.', 'This', 'text'): 1, ('This', 'text', 'can'): 1, ('text', 'can', 'be'): 1, ('can', 'be', 'replaced'): 1, ('be', 'replaced', 'with'): 1, ('replaced', 'with', 'any'): 1, ('with', 'any', 'other'): 1, ('any', 'other', 'text'): 1, ('other', 'text', '.'): 1})

# %%
df = pd.read_csv("final_df.csv")

# %%
unique_skills = []
for index, row in df.iterrows():
    skills = row["SKILLS"].strip('][').split(', ')
    for skill in skills:
        unique_skills.append(skills)

# %%
unique_skills = list(chain.from_iterable(unique_skills))

# %%
i = 0
for skill in unique_skills:
    if skill.startswith("\'") and skill.endswith("\'"):
        unique_skills[i] = skill[1:-1]
    elif skill.startswith("\'") and not(skill.endswith("\'")):
        unique_skills[i] = skill[1:]
    elif not(skill.startswith("\'")) and skill.endswith("\'"):
        unique_skills[i] = skill[:-1]
    else:
        unique_skills[i] = skill
    i += 1

# %%
unique_skills
# Out:
# ['text extraction',
#  'Natural Language Models.',
#  'NLP',
#  'Computer Vision.',
#  'text extraction',
#  'Natural Language Models.',
#  'NLP',
#  'Computer Vision.',
#  'text extraction',
#  'Natural Language Models.',
#  'NLP',
#  'Computer Vision.',
#  'text extraction',
#  'Natural Language Models.',
#  'NLP',
#  'Computer Vision.',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  'TensorFlow',
#  'analyse large datasets',
#  'Supervised and Unsupervised Machine Learning',
#  'statistical methodologies',
#  'Machine learning',
#  'Data Analytics',
#  'feedback loop',
#  'Python',
#  'Deep Learning',
#  'R',
#  'Microsoft Power BI',
#  'training',
#  'Good communication skills',
#  'machine learning',
#  'Jupyter Notebook',
#  'transform large structured and unstructured data sets into valuable insights',
#  'reports and make predictions for business decisions.',
#  'Developing ML algorithms',
#  'feature engineering',
#  'Classification',
#  'ML',
#  'Machine Learning',
#  'Bagging and Boosting algorithms',
#  'numerical',
#  'analytical and statistical skills',
#  'SciKit Learn',
#  'Forecasting',
#  'scaling',
#  'Anomaly Detection',
#  'Neural Networks',
#  'PyTorch',
#  'Run machine learning tests and experiments',
#  'SQL',
#  'Time Series Analysis',
#  'Colab',
#  'data analysis',
#  'Text Mining',
#  'scoring',
#  'Pattern Detection',
#  'machine learning experience',
#  'Decision tree',
#  'Tableau',
#  'data analysis techniques',
#  ...]

# %%
def remove_punct(word):
    for punctuation in [".", ","]:
        word = word.replace(punctuation, '')
    return word

# %%
unique_skills = [remove_punct(skill) for skill in unique_skills]

# %%
unique_skills = " ".join(unique_skills)

# %%
unique_skills
# Out:
# 'text extraction Natural Language Models NLP Computer Vision text extraction Natural Language Models NLP Computer Vision text extraction Natural Language Models NLP Computer Vision text extraction Natural Language Models NLP Computer Vision Data Analytics feedback loop Python Deep Learning R Microsoft Power BI training Good communication skills machine learning Jupyter Notebook transform large structured and unstructured data sets into valuable insights reports and make predictions for business decisions Developing ML algorithms feature engineering Classification ML Machine Learning Bagging and Boosting algorithms numerical analytical and statistical skills SciKit Learn Forecasting scaling Anomaly Detection Neural Networks PyTorch Run machine learning tests and experiments SQL Time Series Analysis Colab data analysis Text Mining scoring Pattern Detection machine learning experience Decision tree Tableau data analysis techniques TensorFlow analyse large datasets Supervised and Unsupervised Machine Learning statistical methodologies Machine learning Data Analytics feedback loop Python Deep Learning R Microsoft Power BI training Good communication skills machine learning Jupyter Notebook transform large structured and unstructured data sets into valuable insights reports and make predictions for business decisions Developing ML algorithms feature engineering Classification ML Machine Learning Bagging and Boosting algorithms numerical analytical and statistical skills SciKit Learn Forecasting scaling Anomaly Detection Neural Networks PyTorch Run machine learning tests and experiments SQL Time Series Analysis Colab data analysis Text Mining scoring Pattern Detection machine learning experience Decision tree Tableau data analysis techniques TensorFlow analyse large datasets Supervised and Unsupervised Machine Learning statistical methodologies Machine learning Data Analytics feedback loop Python Deep Learning R Microsoft Power BI training Good communication skills machine learning Jupyter Notebook transform large structured and unstructured data sets into valuable insights reports and make predictions for business decisions Developing ML algorithms feature engineering Classification ML Machine Learning Bagging and Boosting algorithms numerical analytical and statistical skills SciKit Learn Forecasting scaling Anomaly Detection Neural Networks PyTorch Run machine learning tests and experiments SQL Time Series Analysis Colab data analysis Text Mining scoring Pattern Detection machine learning experience Decision tree Tableau data analysis techniques TensorFlow analyse large datasets Supervised and Unsupervised Machine Learning statistical methodologies Machine learning Data Analytics feedback loop Python Deep Learning R Microsoft Power BI training Good communication skills machine learning Jupyter Notebook transform large structured and unstructured data sets into valuable insights reports and make predictions for business decisions Developing ML algorithms feature engineering Classification ML Machine Learning Bagging and Boosting algorithms numerical analytical and statistical skills SciKit Learn Forecasting scaling Anomaly Detection Neural Networks PyTorch Run machine learning tests and experiments SQL Time Series Analysis Colab data analysis Text Mining scoring Pattern Detection machine learning experience Decision tree Tableau data analysis techniques TensorFlow analyse large datasets Supervised and Unsupervised Machine Learning statistical methodologies Machine learning Data Analytics feedback loop Python Deep Learning R Microsoft Power BI training Good communication skills machine learning Jupyter Notebook transform large structured and unstructured data sets into valuable insights reports and make predictions for business decisions Developing ML algorithms feature engineering Classification ML Machine Learning Bagging and Boosting algorithms numerical analytical and statistical skills SciKit Learn Forecasting scaling Anomaly D ...

# %%
words = nltk.word_tokenize(unique_skills)

# generate trigrams
trigrams = nltk.ngrams(words, 3)

# count the frequency of each trigram
triFreq = Counter(trigrams)

# print the frequency of trigrams
print(triFreq)
# Out:
# Counter({('Full', 'Stack', 'developer'): 64, ('Elasticsearch', 'architecture', 'direction'): 64, ('architecture', 'direction', 'software'): 64, ('direction', 'software', 'design'): 64, ('software', 'design', 'and'): 64, ('design', 'and', 'architecture'): 64, ('and', 'architecture', 'Python'): 64, ('NodeJS', 'Android', 'Java'): 64, ('AI/ML/eCommerce/Digital', 'Health/Marketplaces/Blockchain', 'technologies/solutions'): 64, ('Graphql', 'agile', 'methodologies'): 64, ('Data', 'Analytics', 'feedback'): 43, ('Analytics', 'feedback', 'loop'): 43, ('feedback', 'loop', 'Python'): 43, ('loop', 'Python', 'Deep'): 43, ('Python', 'Deep', 'Learning'): 43, ('Deep', 'Learning', 'R'): 43, ('Learning', 'R', 'Microsoft'): 43, ('R', 'Microsoft', 'Power'): 43, ('Microsoft', 'Power', 'BI'): 43, ('Power', 'BI', 'training'): 43, ('BI', 'training', 'Good'): 43, ('training', 'Good', 'communication'): 43, ('Good', 'communication', 'skills'): 43, ('communication', 'skills', 'machine'): 43, ('skills', 'machine', 'learning'): 43, ('machine', 'learning', 'Jupyter'): 43, ('learning', 'Jupyter', 'Notebook'): 43, ('Jupyter', 'Notebook', 'transform'): 43, ('Notebook', 'transform', 'large'): 43, ('transform', 'large', 'structured'): 43, ('large', 'structured', 'and'): 43, ('structured', 'and', 'unstructured'): 43, ('and', 'unstructured', 'data'): 43, ('unstructured', 'data', 'sets'): 43, ('data', 'sets', 'into'): 43, ('sets', 'into', 'valuable'): 43, ('into', 'valuable', 'insights'): 43, ('valuable', 'insights', 'reports'): 43, ('insights', 'reports', 'and'): 43, ('reports', 'and', 'make'): 43, ('and', 'make', 'predictions'): 43, ('make', 'predictions', 'for'): 43, ('predictions', 'for', 'business'): 43, ('for', 'business', 'decisions'): 43, ('business', 'decisions', 'Developing'): 43, ('decisions', 'Developing', 'ML'): 43, ('Developing', 'ML', 'algorithms'): 43, ('ML', 'algorithms', 'feature'): 43, ('algorithms', 'feature', 'engineering'): 43, ('feature', 'engineering', 'Classification'): 43, ('engineering', 'Classification', 'ML'): 43, ('Classification', 'ML', 'Machine'): 43, ('ML', 'Machine', 'Learning'): 43, ('Machine', 'Learning', 'Bagging'): 43, ('Learning', 'Bagging', 'and'): 43, ('Bagging', 'and', 'Boosting'): 43, ('and', 'Boosting', 'algorithms'): 43, ('Boosting', 'algorithms', 'numerical'): 43, ('algorithms', 'numerical', 'analytical'): 43, ('numerical', 'analytical', 'and'): 43, ('analytical', 'and', 'statistical'): 43, ('and', 'statistical', 'skills'): 43, ('statistical', 'skills', 'SciKit'): 43, ('skills', 'SciKit', 'Learn'): 43, ('SciKit', 'Learn', 'Forecasting'): 43, ('Learn', 'Forecasting', 'scaling'): 43, ('Forecasting', 'scaling', 'Anomaly'): 43, ('scaling', 'Anomaly', 'Detection'): 43, ('Anomaly', 'Detection', 'Neural'): 43, ('Detection', 'Neural', 'Networks'): 43, ('Neural', 'Networks', 'PyTorch'): 43, ('Networks', 'PyTorch', 'Run'): 43, ('PyTorch', 'Run', 'machine'): 43, ('Run', 'machine', 'learning'): 43, ('machine', 'learning', 'tests'): 43, ('learning', 'tests', 'and'): 43, ('tests', 'and', 'experiments'): 43, ('and', 'experiments', 'SQL'): 43, ('experiments', 'SQL', 'Time'): 43, ('SQL', 'Time', 'Series'): 43, ('Time', 'Series', 'Analysis'): 43, ('Series', 'Analysis', 'Colab'): 43, ('Analysis', 'Colab', 'data'): 43, ('Colab', 'data', 'analysis'): 43, ('data', 'analysis', 'Text'): 43, ('analysis', 'Text', 'Mining'): 43, ('Text', 'Mining', 'scoring'): 43, ('Mining', 'scoring', 'Pattern'): 43, ('scoring', 'Pattern', 'Detection'): 43, ('Pattern', 'Detection', 'machine'): 43, ('Detection', 'machine', 'learning'): 43, ('machine', 'learning', 'experience'): 43, ('learning', 'experience', 'Decision'): 43, ('experience', 'Decision', 'tree'): 43, ('Decision', 'tree', 'Tableau'): 43, ('tree', 'Tableau', 'data'): 43, ('Tableau', 'data', 'analysis'): 43, ('data', 'analysis', 'techniques'): 43, ('analysis', 'techniques', 'TensorFlow'): 43, ('techniques', 'TensorFlow', 'analyse'): 43, ('TensorFlow', 'analyse', 'large'): 43, ('analyse', 'large', 'datase ...
